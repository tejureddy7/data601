# %% [markdown]
# # Lab

# %% [markdown]
# Using the flights dataframe answer the following questions

# %% [markdown]
# 1. When do the first and last flights leave each day?
#
# 2. When there is a missing value in `dep_time` then this is an indication of canceled flight. Find the number of cancelled flights for each (`carrier`, `origin`) combination.
#
# 3. Which carrier has the worst `dep_delay`s?
#
# 4. Which plane (`tailnum`) has the worst on-time record?
#
# 5. For each plane, count the number of flights before the first delay of greater than 1 hour.

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/mguner/teaching/main/datasets/nyc_flights/nyc_flights.csv'

# %%
## read the file
flights = pd.read_csv(url)

# %%
#flights.shape

# %%
#flights.columns

# %%
#flights.info()

# %%
flights.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
#
#    distance  hour  minute             time_hour
# 0      1400     5      15  2013-01-01T10:00:00Z
# 1      1416     5      29  2013-01-01T10:00:00Z
# 2      1089     5      40  2013-01-01T10:00:00Z
# 3      1576     5      45  2013-01-01T10:00:00Z
# 4       762     6       0  2013-01-01T11:00:00Z

# %%
#flights.tail()

# %%
### 1. When do the first and last flights leave each day?

# %%
flights.groupby(['day']).agg({'dep_time': [np.min,np.max]})
# Out:
#     dep_time
#         amin    amax
# day
# 1        1.0  2359.0
# 2        3.0  2400.0
# 3        2.0  2359.0
# 4        3.0  2400.0
# 5        1.0  2400.0
# 6        4.0  2359.0
# 7        2.0  2400.0
# 8        1.0  2359.0
# 9        2.0  2400.0
# 10       1.0  2400.0
# 11       1.0  2400.0
# 12       2.0  2400.0
# 13       1.0  2400.0
# 14       3.0  2359.0
# 15       1.0  2400.0
# 16       1.0  2359.0
# 17       2.0  2400.0
# 18       1.0  2359.0
# 19       1.0  2400.0
# 20       1.0  2400.0
# 21       2.0  2400.0
# 22       1.0  2400.0
# 23       4.0  2358.0
# 24       1.0  2359.0
# 25       1.0  2400.0
# 26       1.0  2358.0
# 27       1.0  2400.0
# 28       1.0  2400.0
# 29       2.0  2400.0
# 30       1.0  2400.0
# 31       1.0  2359.0

# %%
def first_last(df):
    return df.iloc[[0, -1]]

# %%
grouped_by_month_day = flights.groupby(['month', 'day']).apply(first_last)

# %%
grouped_by_month_day
# Out:
#                   year  month  day  dep_time  sched_dep_time  dep_delay  \
# month day
# 1     1   0       2013      1    1     517.0             515        2.0
#           841     2013      1    1       NaN             600        NaN
#       2   842     2013      1    2      42.0            2359       43.0
#           1784    2013      1    2       NaN            1601        NaN
#       3   1785    2013      1    3      32.0            2359       33.0
# ...                ...    ...  ...       ...             ...        ...
# 12    29  109551  2013     12   29       NaN            1505        NaN
#       30  109552  2013     12   30       1.0            2359        2.0
#           110519  2013     12   30       NaN             855        NaN
#       31  110520  2013     12   31      13.0            2359       14.0
#           111295  2013     12   31       NaN             830        NaN
#
#                   arr_time  sched_arr_time  arr_delay carrier  flight tailnum  \
# month day
# 1     1   0          830.0             819       11.0      UA    1545  N14228
#           841          NaN             901        NaN      B6     125  N618JB
#       2   842        518.0             442       36.0      B6     707  N580JB
#           1784         NaN            1735        NaN      UA     623     NaN
#       3   1785       504.0             442       22.0      B6     707  N763JB
# ...                    ...             ...        ...     ...     ...     ...
# 12    29  109551       NaN            1811        NaN      UA     455     NaN
#       30  109552     441.0             437        4.0      B6     839  N508JB
#           110519       NaN            1142        NaN      UA    1506     NaN
#       31  110520     439.0             437        2.0      B6     839  N566JB
#           111295       NaN            1154        NaN      UA     443     NaN
#
#                  origin dest  air_time  distance  hour  minute  \
# month day
# 1     1   0         EWR  IAH     227.0      1400     5      15
#           841       JFK  FLL       NaN      1069     6       0
#       2   842       JFK  SJU     189.0      1598    23      59
#           1784      EWR  ORD       NaN       719    16       1
#       3   1785      JFK  SJU     193.0      1598    23      59
# ...                 ...  ...       ...       ...   ...     ...
# 12    29  109551    EWR  MIA       NaN      1085    15       5
#       30  109552    JFK  BQN     198.0      1576    23      59
#           110519    EWR  JAC       NaN      1874     8      55
#       31  110520    JFK  BQN     189.0      1576    23      59
#           111295    JFK  LAX       NaN      2475     8      30
#
#                              time_hour
# month day
# 1     1   0       2013-01-01T10:00:00Z
#           841     2013-01-01T11:00:00Z
#       2   842     2013-01-03T04:00:00Z
#           1784    2013-01-02T21:00:00Z
#       3   1785    2013-01-04T04:00:00Z
# ...                                ...
# 12    29  109551  2013-12-29T20:00:00Z
#       30  109552  2013-12-31T04:00:00Z
#           110519  2013-12-30T13:00:00Z
#       31  110520  2014-01-01T04:00:00Z
#           111295  2013-12-31T13:00:00Z
#
# [730 rows x 19 columns]

# %% [markdown]
# ### 2. When there is a missing value in dep_time then this is an indication of canceled flight. Find the number of cancelled flights for each (carrier, origin) combination.

# %%
df=flights[flights.dep_time.isnull()][['carrier', 'origin']]

# %%
len(df)
# Out:
# 8255

# %% [markdown]
# ### 3. Which carrier has the worst dep_delays?

# %%
#flights.groupby(['carrier', 'origin']).agg({'dep_time': 'count'})

# %%
old=flights.groupby(['carrier']).agg({'dep_delay': 'max'})

# %%
old[old['dep_delay']==old['dep_delay'].max()]
# Out:
#          dep_delay
# carrier
# HA          1301.0

# %% [markdown]
# ### 4. Which plane (tailnum) has the worst on-time record?

# %%
new = flights.groupby(['tailnum']).agg({'arr_delay': 'max'})

# %%
new[new['arr_delay']==new['arr_delay'].max()]
# Out:
#          arr_delay
# tailnum
# N384HA      1272.0

# %%
new['arr_delay'].max()
# Out:
# 1272.0

# %% [markdown]
# ### 5. For each plane, count the number of flights before the first delay of greater than 1 hour.

# %%
count=0
for name, group in flights.groupby(['day', 'tailnum']):
         for index, row in group.iterrows():
                    if row['dep_delay']  < 60:
                         count +=1
                    else:
                         print('index, day, count',(row['tailnum'],row['day'], count))
                         count = 0
                         break
# Out:
# index, day, count ('N104UW', 1, 21)
# index, day, count ('N10575', 1, 5)
# index, day, count ('N11109', 1, 28)
# index, day, count ('N11127', 1, 11)
# index, day, count ('N11140', 1, 2)
# index, day, count ('N11150', 1, 3)
# index, day, count ('N11176', 1, 5)
# index, day, count ('N11193', 1, 13)
# index, day, count ('N11194', 1, 6)
# index, day, count ('N11199', 1, 2)
# index, day, count ('N11206', 1, 3)
# index, day, count ('N11535', 1, 5)
# index, day, count ('N11536', 1, 1)
# index, day, count ('N11547', 1, 15)
# index, day, count ('N11548', 1, 6)
# index, day, count ('N11551', 1, 3)
# index, day, count ('N11565', 1, 6)
# index, day, count ('N12122', 1, 8)
# index, day, count ('N12126', 1, 9)
# index, day, count ('N12135', 1, 0)
# index, day, count ('N12142', 1, 5)
# index, day, count ('N12160', 1, 14)
# index, day, count ('N12216', 1, 34)
# index, day, count ('N122US', 1, 11)
# index, day, count ('N12540', 1, 8)
# index, day, count ('N12552', 1, 3)
# index, day, count ('N12563', 1, 0)
# index, day, count ('N12564', 1, 5)
# index, day, count ('N12567', 1, 8)
# index, day, count ('N12569', 1, 3)
# index, day, count ('N12900', 1, 6)
# index, day, count ('N12921', 1, 6)
# index, day, count ('N12922', 1, 3)
# index, day, count ('N12957', 1, 5)
# index, day, count ('N12996', 1, 6)
# index, day, count ('N13118', 1, 6)
# index, day, count ('N13123', 1, 1)
# index, day, count ('N13124', 1, 1)
# index, day, count ('N13138', 1, 9)
# index, day, count ('N13161', 1, 1)
# index, day, count ('N132EV', 1, 11)
# index, day, count ('N13538', 1, 4)
# index, day, count ('N13550', 1, 1)
# index, day, count ('N13553', 1, 7)
# index, day, count ('N13566', 1, 2)
# index, day, count ('N13716', 1, 7)
# index, day, count ('N13903', 1, 5)
# index, day, count ('N13913', 1, 9)
# index, day, count ('N13949', 1, 7)
# index, day, count ('N13956', 1, 14)
# index, day, count ('N13958', 1, 2)
# index, day, count ('N13964', 1, 3)
# index, day, count ('N13965', 1, 6)
# index, day, count ('N13968', 1, 5)
# index, day, count ('N13969', 1, 7)
# index, day, count ('N13970', 1, 4)
# index, day, count ('N13975', 1, 2)
# index, day, count ('N13978', 1, 2)
# index, day, count ('N13988', 1, 9)
# index, day, count ('N13989', 1, 2)
# index, day, count ('N13992', 1, 0)
# index, day, count ('N13994', 1, 0)
# index, day, count ('N14105', 1, 17)
# index, day, count ('N14116', 1, 14)
# index, day, count ('N14117', 1, 1)
# index, day, count ('N14125', 1, 15)
# index, day, count ('N14143', 1, 0)
# index, day, count ('N14168', 1, 15)
# index, day, count ('N14174', 1, 13)
# index, day, count ('N14179', 1, 1)
# index, day, count ('N14180', 1, 3)
# index, day, count ('N14186', 1, 0)
# index, day, count ('N14198', 1, 5)
# index, day, count ('N14204', 1, 10)
# index, day, count ('N14231', 1, 12)
# index, day, count ('N14237', 1, 0)
# index, day, count ('N14242', 1, 2)
# index, day, count ('N14542', 1, 17)
# index, day, count ('N14543', 1, 1)
# index, day, count ('N14558', 1, 7)
# index, day, count ('N14562', 1, 2)
# index, day, count ('N14568', 1, 1)
# index, day, count ('N14573', 1, 15)
# index, day, count ('N146PQ', 1, 0)
# index, day, count ('N14905', 1, 29)
# index, day, count ('N14907', 1, 1)
# index, day, count ('N14916', 1, 5)
# index, day, count ('N14920', 1, 4)
# index, day, count ('N14923', 1, 3)
# index, day, count ('N14950', 1, 0)
# index, day, count ('N14952', 1, 1)
# index, day, count ('N14953', 1, 2)
# index, day, count ('N14959', 1, 0)
# index, day, count ('N14960', 1, 2)
# index, day, count ('N14972', 1, 1)
# index, day, count ('N14974', 1, 4)
# index, day, count ('N14977', 1, 1)
# index, day, count ('N14998', 1, 20)
# index, day, count ('N15555', 1, 13)
# index, day, count ('N15572', 1, 3)
# index, day, count ('N15574', 1, 2)
# index, day, count ('N156DL', 1, 1)
# index, day, count ('N15910', 1, 8)
# index, day, count ('N15973', 1, 20)
# index, day, count ('N15980', 1, 3)
# index, day, count ('N15983', 1, 2)
# index, day, count ('N15985', 1, 3)
# index, day, count ('N16151', 1, 24)
# index, day, count ('N16170', 1, 1)
# index, day, count ('N16541', 1, 17)
# index, day, count ('N16546', 1, 5)
# index, day, count ('N16559', 1, 0)
# index, day, count ('N16561', 1, 0)
# index, day, count ('N16571', 1, 3)
# index, day, count ('N16701', 1, 8)
# index, day, count ('N16732', 1, 18)
# index, day, count ('N168AT', 1, 3)
# index, day, count ('N16911', 1, 0)
# index, day, count ('N16918', 1, 2)
# index, day, count ('N16919', 1, 1)
# index, day, count ('N16961', 1, 11)
# index, day, count ('N16963', 1, 6)
# index, day, count ('N16981', 1, 9)
# index, day, count ('N16987', 1, 4)
# index, day, count ('N17115', 1, 29)
# index, day, count ('N17159', 1, 25)
# index, day, count ('N17185', 1, 2)
# index, day, count ('N17196', 1, 1)
# index, day, count ('N17229', 1, 4)
# index, day, count ('N17560', 1, 28)
# index, day, count ('N17730', 1, 18)
# index, day, count ('N178JB', 1, 18)
# index, day, count ('N17984', 1, 4)
# index, day, count ('N18102', 1, 11)
# index, day, count ('N18114', 1, 5)
# index, day, count ('N18120', 1, 4)
# index, day, count ('N183JB', 1, 26)
# index, day, count ('N184DN', 1, 0)
# index, day, count ('N184JB', 1, 3)
# index, day, count ('N18556', 1, 1)
# index, day, count ('N18557', 1, 0)
# index, day, count ('N186DN', 1, 2)
# index, day, count ('N186US', 1, 3)
# index, day, count ('N188DN', 1, 13)
# index, day, count ('N189UW', 1, 10)
# index, day, count ('N192JB', 1, 44)
# index, day, count ('N192UW', 1, 2)
# index, day, count ('N19554', 1, 24)
# index, day, count ('N195UW', 1, 8)
# index, day, count ('N197JB', 1, 6)
# index, day, count ('N19966', 1, 16)
# index, day, count ('N201AA', 1, 12)
# index, day, count ('N201FR', 1, 0)
# index, day, count ('N205FR', 1, 24)
# index, day, count ('N21129', 1, 23)
# index, day, count ('N21130', 1, 2)
# index, day, count ('N21144', 1, 2)
# index, day, count ('N21154', 1, 5)
# index, day, count ('N21197', 1, 0)
# index, day, count ('N212WN', 1, 2)
# index, day, count ('N214FR', 1, 2)
# index, day, count ('N21537', 1, 1)
# index, day, count ('N216JB', 1, 18)
# index, day, count ('N21723', 1, 5)
# index, day, count ('N217JC', 1, 0)
# index, day, count ('N223WN', 1, 7)
# index, day, count ('N228JB', 1, 15)
# index, day, count ('N22971', 1, 16)
# index, day, count ('N229JB', 1, 5)
# index, day, count ('N231JB', 1, 10)
# index, day, count ('N232PQ', 1, 1)
# index, day, count ('N232WN', 1, 1)
# index, day, count ('N235WN', 1, 1)
# index, day, count ('N23707', 1, 12)
# index, day, count ('N23708', 1, 3)
# index, day, count ('N237WN', 1, 4)
# index, day, count ('N238JB', 1, 1)
# index, day, count ('N238WN', 1, 2)
# index, day, count ('N239JB', 1, 1)
# index, day, count ('N24212', 1, 21)
# index, day, count ('N244WN', 1, 9)
# index, day, count ('N24715', 1, 15)
# index, day, count ('N249JB', 1, 16)
# index, day, count ('N258JB', 1, 18)
# index, day, count ('N263AV', 1, 32)
# index, day, count ('N26545', 1, 3)
# index, day, count ('N26549', 1, 2)
# index, day, count ('N265JB', 1, 1)
# index, day, count ('N266JB', 1, 0)
# index, day, count ('N266WN', 1, 2)
# index, day, count ('N267JB', 1, 11)
# index, day, count ('N268WN', 1, 2)
# index, day, count ('N270WN', 1, 6)
# index, day, count ('N27190', 1, 4)
# index, day, count ('N273JB', 1, 25)
# index, day, count ('N27421', 1, 5)
# index, day, count ('N274JB', 1, 7)
# index, day, count ('N27724', 1, 13)
# index, day, count ('N27962', 1, 12)
# index, day, count ('N281AT', 1, 14)
# index, day, count ('N281JB', 1, 10)
# index, day, count ('N284JB', 1, 19)
# index, day, count ('N29129', 1, 16)
# index, day, count ('N293PQ', 1, 19)
# index, day, count ('N294JB', 1, 2)
# index, day, count ('N296JB', 1, 8)
# index, day, count ('N296WN', 1, 2)
# index, day, count ('N29717', 1, 5)
# index, day, count ('N298JB', 1, 20)
# index, day, count ('N29917', 1, 7)
# index, day, count ('N304JB', 1, 35)
# index, day, count ('N307JB', 1, 35)
# index, day, count ('N308DE', 1, 7)
# index, day, count ('N310DE', 1, 15)
# index, day, count ('N31131', 1, 12)
# index, day, count ('N311US', 1, 4)
# index, day, count ('N314NB', 1, 10)
# index, day, count ('N318JB', 1, 60)
# index, day, count ('N319US', 1, 36)
# index, day, count ('N320AA', 1, 9)
# index, day, count ('N321US', 1, 27)
# index, day, count ('N322NB', 1, 7)
# index, day, count ('N323AA', 1, 4)
# index, day, count ('N323NB', 1, 11)
# index, day, count ('N324AA', 1, 10)
# index, day, count ('N324JB', 1, 5)
# index, day, count ('N326US', 1, 32)
# index, day, count ('N327AA', 1, 6)
# index, day, count ('N328AA', 1, 22)
# index, day, count ('N328JB', 1, 0)
# index, day, count ('N329JB', 1, 21)
# index, day, count ('N33182', 1, 24)
# index, day, count ('N33203', 1, 5)
# index, day, count ('N33264', 1, 9)
# index, day, count ('N33266', 1, 2)
# index, day, count ('N33292', 1, 12)
# index, day, count ('N332AA', 1, 2)
# index, day, count ('N333NW', 1, 16)
# index, day, count ('N334NB', 1, 11)
# index, day, count ('N335AA', 1, 5)
# index, day, count ('N336AA', 1, 9)
# index, day, count ('N336NB', 1, 9)
# index, day, count ('N338AA', 1, 28)
# index, day, count ('N338NB', 1, 9)
# index, day, count ('N339JB', 1, 25)
# index, day, count ('N34110', 1, 21)
# index, day, count ('N34111', 1, 0)
# index, day, count ('N341NB', 1, 11)
# index, day, count ('N341NW', 1, 2)
# index, day, count ('N34282', 1, 6)
# index, day, count ('N342AA', 1, 1)
# index, day, count ('N342NW', 1, 3)
# index, day, count ('N343NB', 1, 3)
# index, day, count ('N346JB', 1, 32)
# index, day, count ('N347NW', 1, 11)
# index, day, count ('N348JB', 1, 1)
# index, day, count ('N348NB', 1, 5)
# index, day, count ('N351JB', 1, 20)
# index, day, count ('N353JB', 1, 20)
# index, day, count ('N35407', 1, 11)
# index, day, count ('N354AT', 1, 1)
# index, day, count ('N355JB', 1, 16)
# index, day, count ('N356NW', 1, 14)
# index, day, count ('N358JB', 1, 14)
# index, day, count ('N36207', 1, 48)
# index, day, count ('N36247', 1, 0)
# index, day, count ('N36469', 1, 32)
# index, day, count ('N364NB', 1, 1)
# index, day, count ('N36915', 1, 33)
# index, day, count ('N369AA', 1, 0)
# index, day, count ('N369NW', 1, 5)
# index, day, count ('N370NW', 1, 7)
# index, day, count ('N372NW', 1, 70)
# index, day, count ('N3735D', 1, 22)
# index, day, count ('N3736C', 1, 5)
# index, day, count ('N373JB', 1, 28)
# index, day, count ('N3740C', 1, 10)
# index, day, count ('N3745B', 1, 36)
# index, day, count ('N37470', 1, 26)
# index, day, count ('N37471', 1, 4)
# index, day, count ('N3747D', 1, 5)
# index, day, count ('N374DA', 1, 14)
# index, day, count ('N374JB', 1, 7)
# index, day, count ('N3759', 1, 40)
# index, day, count ('N3762Y', 1, 18)
# index, day, count ('N3764D', 1, 5)
# index, day, count ('N378NW', 1, 66)
# index, day, count ('N383DN', 1, 20)
# index, day, count ('N38451', 1, 11)
# index, day, count ('N384DA', 1, 11)
# index, day, count ('N391CA', 1, 47)
# index, day, count ('N392DA', 1, 8)
# index, day, count ('N39415', 1, 3)
# index, day, count ('N39475', 1, 24)
# index, day, count ('N394DA', 1, 2)
# index, day, count ('N395DN', 1, 4)
# index, day, count ('N398CA', 1, 26)
# index, day, count ('N398DA', 1, 3)
# index, day, count ('N3AAAA', 1, 5)
# index, day, count ('N3AFAA', 1, 22)
# index, day, count ('N3AJAA', 1, 4)
# index, day, count ('N3BEAA', 1, 34)
# index, day, count ('N3BFAA', 1, 1)
# index, day, count ('N3BRAA', 1, 13)
# index, day, count ('N3CAAA', 1, 15)
# index, day, count ('N3CDAA', 1, 7)
# index, day, count ('N3CWAA', 1, 32)
# index, day, count ('N3CYAA', 1, 1)
# index, day, count ('N3DJAA', 1, 12)
# index, day, count ('N3EBAA', 1, 31)
# index, day, count ('N3EEAA', 1, 5)
# index, day, count ('N3EHAA', 1, 5)
# index, day, count ('N3ESAA', 1, 17)
# index, day, count ('N3EVAA', 1, 7)
# index, day, count ('N3FLAA', 1, 22)
# index, day, count ('N3FUAA', 1, 19)
# index, day, count ('N3FVAA', 1, 1)
# index, day, count ('N3GAAA', 1, 12)
# index, day, count ('N3GGAA', 1, 17)
# index, day, count ('N3GTAA', 1, 25)
# index, day, count ('N3GVAA', 1, 1)
# index, day, count ('N3HEAA', 1, 12)
# index, day, count ('N3HPAA', 1, 29)
# index, day, count ('N3HSAA', 1, 3)
# index, day, count ('N3HTAA', 1, 7)
# index, day, count ('N3HYAA', 1, 9)
# index, day, count ('N3JFAA', 1, 9)
# index, day, count ('N3JLAA', 1, 9)
# index, day, count ('N3JMAA', 1, 0)
# index, day, count ('N3JNAA', 1, 0)
# index, day, count ('N3JSAA', 1, 1)
# index, day, count ('N3KFAA', 1, 28)
# index, day, count ('N3KLAA', 1, 10)
# index, day, count ('N3KVAA', 1, 8)
# index, day, count ('N401WN', 1, 5)
# index, day, count ('N403AA', 1, 7)
# index, day, count ('N405UA', 1, 8)
# index, day, count ('N413AS', 1, 23)
# index, day, count ('N414UA', 1, 7)
# index, day, count ('N419AS', 1, 15)
# index, day, count ('N420UA', 1, 5)
# index, day, count ('N421UA', 1, 6)
# index, day, count ('N422UA', 1, 0)
# index, day, count ('N422WN', 1, 2)
# index, day, count ('N426AA', 1, 16)
# index, day, count ('N433UA', 1, 38)
# index, day, count ('N434AA', 1, 1)
# index, day, count ('N435UA', 1, 6)
# index, day, count ('N437AA', 1, 6)
# index, day, count ('N437WN', 1, 4)
# index, day, count ('N439AA', 1, 5)
# index, day, count ('N440LV', 1, 6)
# index, day, count ('N446UA', 1, 26)
# index, day, count ('N447UA', 1, 0)
# index, day, count ('N449UA', 1, 3)
# index, day, count ('N454UA', 1, 19)
# index, day, count ('N454WN', 1, 0)
# index, day, count ('N462WN', 1, 38)
# index, day, count ('N467WN', 1, 27)
# index, day, count ('N471AA', 1, 16)
# index, day, count ('N473UA', 1, 11)
# index, day, count ('N475UA', 1, 17)
# index, day, count ('N480UA', 1, 25)
# index, day, count ('N481UA', 1, 5)
# index, day, count ('N485WN', 1, 20)
# index, day, count ('N48901', 1, 19)
# index, day, count ('N491UA', 1, 17)
# index, day, count ('N4WRAA', 1, 52)
# index, day, count ('N4WSAA', 1, 2)
# index, day, count ('N4XSAA', 1, 20)
# index, day, count ('N4YDAA', 1, 18)
# index, day, count ('N4YRAA', 1, 24)
# index, day, count ('N500MQ', 1, 6)
# index, day, count ('N501MQ', 1, 8)
# index, day, count ('N502MQ', 1, 3)
# index, day, count ('N503AA', 1, 10)
# index, day, count ('N503JB', 1, 6)
# index, day, count ('N504MQ', 1, 11)
# index, day, count ('N506MQ', 1, 41)
# index, day, count ('N507AY', 1, 0)
# index, day, count ('N507JB', 1, 4)
# index, day, count ('N507MJ', 1, 1)
# index, day, count ('N507MQ', 1, 6)
# index, day, count ('N508JB', 1, 18)
# index, day, count ('N508MQ', 1, 12)
# index, day, count ('N508UA', 1, 4)
# index, day, count ('N509JB', 1, 8)
# index, day, count ('N509MJ', 1, 0)
# index, day, count ('N509MQ', 1, 7)
# index, day, count ('N510JB', 1, 8)
# index, day, count ('N510MQ', 1, 9)
# index, day, count ('N510UA', 1, 3)
# index, day, count ('N511MQ', 1, 12)
# index, day, count ('N513MJ', 1, 18)
# index, day, count ('N513MQ', 1, 16)
# index, day, count ('N514MQ', 1, 12)
# index, day, count ('N516JB', 1, 28)
# index, day, count ('N517JB', 1, 13)
# index, day, count ('N518MQ', 1, 17)
# index, day, count ('N519AA', 1, 7)
# index, day, count ('N519JB', 1, 4)
# index, day, count ('N519MQ', 1, 5)
# index, day, count ('N520JB', 1, 9)
# index, day, count ('N521JB', 1, 27)
# index, day, count ('N521MQ', 1, 5)
# index, day, count ('N521VA', 1, 8)
# index, day, count ('N522AA', 1, 1)
# index, day, count ('N523JB', 1, 18)
# index, day, count ('N523MQ', 1, 3)
# index, day, count ('N523UA', 1, 4)
# index, day, count ('N524JB', 1, 3)
# index, day, count ('N524UA', 1, 9)
# index, day, count ('N525AA', 1, 2)
# index, day, count ('N525MQ', 1, 8)
# index, day, count ('N526JB', 1, 13)
# index, day, count ('N526MQ', 1, 5)
# index, day, count ('N527MQ', 1, 13)
# index, day, count ('N528MQ', 1, 16)
# index, day, count ('N530MQ', 1, 19)
# index, day, count ('N530VA', 1, 3)
# index, day, count ('N531JB', 1, 3)
# index, day, count ('N531MQ', 1, 0)
# index, day, count ('N532MQ', 1, 10)
# index, day, count ('N534JB', 1, 20)
# index, day, count ('N534MQ', 1, 1)
# index, day, count ('N534UA', 1, 0)
# index, day, count ('N535JB', 1, 7)
# index, day, count ('N535MQ', 1, 5)
# index, day, count ('N536UA', 1, 18)
# index, day, count ('N537JB', 1, 17)
# index, day, count ('N537UW', 1, 13)
# index, day, count ('N538CA', 1, 2)
# index, day, count ('N538UW', 1, 5)
# index, day, count ('N541UW', 1, 34)
# index, day, count ('N542MQ', 1, 7)
# index, day, count ('N543MQ', 1, 8)
# index, day, count ('N544MQ', 1, 8)
# index, day, count ('N545UA', 1, 4)
# index, day, count ('N547AA', 1, 18)
# index, day, count ('N547JB', 1, 11)
# index, day, count ('N549UW', 1, 14)
# index, day, count ('N552JB', 1, 14)
# index, day, count ('N552NW', 1, 0)
# index, day, count ('N554JB', 1, 15)
# index, day, count ('N556JB', 1, 28)
# index, day, count ('N558JB', 1, 25)
# index, day, count ('N559AA', 1, 8)
# index, day, count ('N560UW', 1, 27)
# index, day, count ('N561JB', 1, 2)
# index, day, count ('N564JB', 1, 34)
# index, day, count ('N565AA', 1, 12)
# index, day, count ('N565UA', 1, 11)
# index, day, count ('N566AA', 1, 2)
# index, day, count ('N566JB', 1, 8)
# index, day, count ('N569UA', 1, 35)
# index, day, count ('N570JB', 1, 1)
# index, day, count ('N57111', 1, 7)
# index, day, count ('N572UA', 1, 14)
# index, day, count ('N573AA', 1, 2)
# index, day, count ('N57439', 1, 7)
# index, day, count ('N576AA', 1, 8)
# index, day, count ('N579JB', 1, 25)
# index, day, count ('N580JB', 1, 8)
# index, day, count ('N58101', 1, 6)
# index, day, count ('N582AA', 1, 5)
# index, day, count ('N584JB', 1, 21)
# index, day, count ('N586UA', 1, 26)
# index, day, count ('N587AA', 1, 1)
# index, day, count ('N587NW', 1, 6)
# index, day, count ('N587UA', 1, 1)
# index, day, count ('N588UA', 1, 9)
# index, day, count ('N589JB', 1, 12)
# index, day, count ('N590JB', 1, 14)
# index, day, count ('N592JB', 1, 16)
# index, day, count ('N593JB', 1, 8)
# index, day, count ('N594JB', 1, 8)
# index, day, count ('N594UA', 1, 0)
# index, day, count ('N595JB', 1, 5)
# index, day, count ('N595UA', 1, 5)
# index, day, count ('N599JB', 1, 33)
# index, day, count ('N5DLAA', 1, 21)
# index, day, count ('N5DNAA', 1, 1)
# index, day, count ('N5EAAA', 1, 12)
# index, day, count ('N5EVAA', 1, 23)
# index, day, count ('N5FTAA', 1, 51)
# index, day, count ('N5PBMQ', 1, 4)
# index, day, count ('N600LR', 1, 2)
# index, day, count ('N600MQ', 1, 0)
# index, day, count ('N601LR', 1, 8)
# index, day, count ('N603JB', 1, 20)
# index, day, count ('N604AW', 1, 3)
# index, day, count ('N605JB', 1, 15)
# index, day, count ('N607JB', 1, 26)
# index, day, count ('N607MQ', 1, 1)
# index, day, count ('N608JB', 1, 5)
# index, day, count ('N608QX', 1, 4)
# index, day, count ('N609SW', 1, 4)
# index, day, count ('N612JB', 1, 17)
# index, day, count ('N612QX', 1, 4)
# index, day, count ('N613JB', 1, 7)
# index, day, count ('N614QX', 1, 2)
# index, day, count ('N614SW', 1, 0)
# index, day, count ('N615QX', 1, 10)
# index, day, count ('N617MQ', 1, 7)
# index, day, count ('N618JB', 1, 3)
# index, day, count ('N621JB', 1, 13)
# index, day, count ('N623JB', 1, 19)
# index, day, count ('N623MQ', 1, 0)
# index, day, count ('N624JB', 1, 24)
# index, day, count ('N626VA', 1, 21)
# index, day, count ('N627MQ', 1, 11)
# index, day, count ('N627VA', 1, 3)
# index, day, count ('N628VA', 1, 5)
# index, day, count ('N629JB', 1, 0)
# index, day, count ('N630VA', 1, 19)
# index, day, count ('N631VA', 1, 7)
# index, day, count ('N633JB', 1, 24)
# index, day, count ('N634VA', 1, 17)
# index, day, count ('N635DL', 1, 2)
# index, day, count ('N635VA', 1, 13)
# index, day, count ('N636JB', 1, 0)
# index, day, count ('N636VA', 1, 4)
# index, day, count ('N637JB', 1, 7)
# index, day, count ('N638JB', 1, 11)
# index, day, count ('N640JB', 1, 27)
# index, day, count ('N641DL', 1, 6)
# index, day, count ('N641JB', 1, 1)
# index, day, count ('N641VA', 1, 2)
# index, day, count ('N642AA', 1, 0)
# index, day, count ('N645JB', 1, 40)
# index, day, count ('N648JB', 1, 27)
# index, day, count ('N651AW', 1, 11)
# index, day, count ('N651DL', 1, 0)
# index, day, count ('N651JB', 1, 1)
# index, day, count ('N652JB', 1, 12)
# index, day, count ('N653AW', 1, 0)
# index, day, count ('N653JB', 1, 6)
# index, day, count ('N655JB', 1, 21)
# index, day, count ('N657AW', 1, 14)
# index, day, count ('N657JB', 1, 10)
# index, day, count ('N658JB', 1, 4)
# index, day, count ('N66056', 1, 14)
# index, day, count ('N660AW', 1, 0)
# index, day, count ('N662MQ', 1, 30)
# index, day, count ('N663JB', 1, 13)
# index, day, count ('N667AW', 1, 30)
# index, day, count ('N6704Z', 1, 17)
# index, day, count ('N67058', 1, 1)
# index, day, count ('N6714Q', 1, 13)
# index, day, count ('N673MQ', 1, 18)
# index, day, count ('N678AW', 1, 20)
# index, day, count ('N679DA', 1, 5)
# index, day, count ('N688MQ', 1, 32)
# index, day, count ('N689MQ', 1, 0)
# index, day, count ('N691CA', 1, 5)
# index, day, count ('N695DL', 1, 12)
# index, day, count ('N6EAMQ', 1, 7)
# index, day, count ('N703JB', 1, 21)
# index, day, count ('N703SW', 1, 0)
# index, day, count ('N703TW', 1, 2)
# index, day, count ('N705JB', 1, 14)
# index, day, count ('N705TW', 1, 7)
# index, day, count ('N706JB', 1, 2)
# index, day, count ('N706SW', 1, 0)
# index, day, count ('N707EV', 1, 6)
# index, day, count ('N708EV', 1, 8)
# index, day, count ('N709EV', 1, 18)
# index, day, count ('N709JB', 1, 10)
# index, day, count ('N710EV', 1, 14)
# index, day, count ('N711MQ', 1, 19)
# index, day, count ('N712EV', 1, 17)
# index, day, count ('N712US', 1, 14)
# index, day, count ('N713EV', 1, 0)
# index, day, count ('N713MQ', 1, 9)
# index, day, count ('N716EV', 1, 32)
# index, day, count ('N717EV', 1, 5)
# index, day, count ('N717MQ', 1, 5)
# index, day, count ('N718EV', 1, 9)
# index, day, count ('N720EV', 1, 20)
# index, day, count ('N720MQ', 1, 7)
# index, day, count ('N721MQ', 1, 4)
# index, day, count ('N722EV', 1, 14)
# index, day, count ('N722MQ', 1, 9)
# index, day, count ('N723EV', 1, 18)
# index, day, count ('N723MQ', 1, 11)
# index, day, count ('N723SW', 1, 1)
# index, day, count ('N723UW', 1, 13)
# index, day, count ('N724EV', 1, 2)
# index, day, count ('N724MQ', 1, 0)
# index, day, count ('N725MQ', 1, 9)
# index, day, count ('N730EV', 1, 27)
# index, day, count ('N730US', 1, 14)
# index, day, count ('N73270', 1, 11)
# index, day, count ('N73276', 1, 5)
# index, day, count ('N73445', 1, 24)
# index, day, count ('N734MQ', 1, 2)
# index, day, count ('N734SA', 1, 2)
# index, day, count ('N735MQ', 1, 9)
# index, day, count ('N737JW', 1, 10)
# index, day, count ('N738EV', 1, 11)
# index, day, count ('N738MQ', 1, 6)
# index, day, count ('N740EV', 1, 14)
# index, day, count ('N741EV', 1, 7)
# index, day, count ('N741UW', 1, 2)
# index, day, count ('N744EV', 1, 4)
# index, day, count ('N745VJ', 1, 12)
# index, day, count ('N746JB', 1, 10)
# index, day, count ('N746UW', 1, 2)
# index, day, count ('N748EV', 1, 11)
# index, day, count ('N750UW', 1, 23)
# index, day, count ('N751EV', 1, 2)
# index, day, count ('N752EV', 1, 10)
# index, day, count ('N752US', 1, 7)
# index, day, count ('N753EV', 1, 1)
# index, day, count ('N75425', 1, 8)
# index, day, count ('N754EV', 1, 32)
# index, day, count ('N755EV', 1, 1)
# index, day, count ('N757UW', 1, 16)
# index, day, count ('N75853', 1, 2)
# index, day, count ('N759EV', 1, 19)
# index, day, count ('N760JB', 1, 19)
# index, day, count ('N761ND', 1, 3)
# index, day, count ('N761RR', 1, 0)
# index, day, count ('N76265', 1, 6)
# index, day, count ('N76502', 1, 36)
# index, day, count ('N76503', 1, 5)
# index, day, count ('N76516', 1, 27)
# index, day, count ('N76528', 1, 28)
# index, day, count ('N765SW', 1, 5)
# index, day, count ('N769SW', 1, 33)
# index, day, count ('N7702A', 1, 5)
# index, day, count ('N771SA', 1, 13)
# index, day, count ('N77258', 1, 6)
# index, day, count ('N7730A', 1, 12)
# index, day, count ('N7734H', 1, 1)
# index, day, count ('N7735A', 1, 1)
# index, day, count ('N775JB', 1, 37)
# index, day, count ('N779JB', 1, 10)
# index, day, count ('N78285', 1, 4)
# index, day, count ('N78448', 1, 11)
# index, day, count ('N784NC', 1, 9)
# index, day, count ('N78524', 1, 11)
# index, day, count ('N789JB', 1, 11)
# index, day, count ('N79402', 1, 21)
# index, day, count ('N794JB', 1, 8)
# index, day, count ('N800MQ', 1, 24)
# index, day, count ('N802UA', 1, 7)
# index, day, count ('N805JB', 1, 28)
# index, day, count ('N806JB', 1, 8)
# index, day, count ('N808MQ', 1, 28)
# index, day, count ('N810MQ', 1, 14)
# index, day, count ('N811MQ', 1, 5)
# index, day, count ('N813AY', 1, 7)
# index, day, count ('N813UA', 1, 5)
# index, day, count ('N81449', 1, 2)
# index, day, count ('N816MQ', 1, 18)
# index, day, count ('N817MQ', 1, 7)
# index, day, count ('N818UA', 1, 5)
# index, day, count ('N820AS', 1, 8)
# index, day, count ('N821JB', 1, 16)
# index, day, count ('N822UA', 1, 8)
# index, day, count ('N823UA', 1, 3)
# index, day, count ('N824UA', 1, 4)
# index, day, count ('N825AS', 1, 2)
# index, day, count ('N826AS', 1, 6)
# index, day, count ('N827AS', 1, 6)
# index, day, count ('N827JB', 1, 3)
# index, day, count ('N829AS', 1, 33)
# index, day, count ('N830AS', 1, 8)
# index, day, count ('N830AY', 1, 1)
# index, day, count ('N830MQ', 1, 2)
# index, day, count ('N830UA', 1, 0)
# index, day, count ('N831UA', 1, 7)
# index, day, count ('N832AS', 1, 6)
# index, day, count ('N832AY', 1, 2)
# index, day, count ('N832MQ', 1, 2)
# index, day, count ('N832UA', 1, 5)
# index, day, count ('N833AS', 1, 4)
# index, day, count ('N834UA', 1, 22)
# index, day, count ('N835MQ', 1, 10)
# index, day, count ('N836AS', 1, 6)
# index, day, count ('N844MQ', 1, 84)
# index, day, count ('N844UA', 1, 3)
# index, day, count ('N8458A', 1, 3)
# index, day, count ('N846MQ', 1, 8)
# index, day, count ('N847MQ', 1, 9)
# index, day, count ('N848MQ', 1, 12)
# index, day, count ('N8515F', 1, 28)
# index, day, count ('N852MQ', 1, 12)
# index, day, count ('N852UA', 1, 1)
# index, day, count ('N854MQ', 1, 24)
# index, day, count ('N8554A', 1, 4)
# index, day, count ('N8560F', 1, 5)
# index, day, count ('N8604C', 1, 18)
# index, day, count ('N8611A', 1, 6)
# index, day, count ('N8672A', 1, 6)
# index, day, count ('N8674A', 1, 2)
# index, day, count ('N87513', 1, 28)
# index, day, count ('N8783E', 1, 22)
# index, day, count ('N8886A', 1, 29)
# index, day, count ('N8888D', 1, 1)
# index, day, count ('N8932C', 1, 27)
# index, day, count ('N8936A', 1, 5)
# index, day, count ('N8938A', 1, 1)
# index, day, count ('N894AT', 1, 11)
# index, day, count ('N8971A', 1, 12)
# index, day, count ('N8980A', 1, 8)
# index, day, count ('N8EGMQ', 1, 8)
# index, day, count ('N901XJ', 1, 14)
# index, day, count ('N903DE', 1, 8)
# index, day, count ('N903WN', 1, 0)
# index, day, count ('N903XJ', 1, 2)
# index, day, count ('N904DE', 1, 3)
# index, day, count ('N904XJ', 1, 5)
# index, day, count ('N905XJ', 1, 7)
# index, day, count ('N906AT', 1, 1)
# index, day, count ('N907DE', 1, 19)
# index, day, count ('N907DL', 1, 0)
# index, day, count ('N907XJ', 1, 5)
# index, day, count ('N908DL', 1, 3)
# index, day, count ('N909MQ', 1, 25)
# index, day, count ('N910DE', 1, 10)
# index, day, count ('N910XJ', 1, 9)
# index, day, count ('N911DE', 1, 1)
# index, day, count ('N912DE', 1, 3)
# index, day, count ('N912XJ', 1, 10)
# index, day, count ('N913XJ', 1, 12)
# index, day, count ('N914DL', 1, 2)
# index, day, count ('N914WN', 1, 1)
# index, day, count ('N914XJ', 1, 5)
# index, day, count ('N915WN', 1, 7)
# index, day, count ('N915XJ', 1, 6)
# index, day, count ('N917XJ', 1, 24)
# index, day, count ('N918DE', 1, 3)
# index, day, count ('N918XJ', 1, 8)
# index, day, count ('N919DL', 1, 4)
# index, day, count ('N920FJ', 1, 20)
# index, day, count ('N920XJ', 1, 10)
# index, day, count ('N921DL', 1, 3)
# index, day, count ('N921XJ', 1, 4)
# index, day, count ('N922FJ', 1, 9)
# index, day, count ('N922WN', 1, 0)
# index, day, count ('N922XJ', 1, 7)
# index, day, count ('N923DL', 1, 4)
# index, day, count ('N923DN', 1, 0)
# index, day, count ('N923XJ', 1, 9)
# index, day, count ('N924DL', 1, 3)
# index, day, count ('N924XJ', 1, 1)
# index, day, count ('N925WN', 1, 2)
# index, day, count ('N925XJ', 1, 2)
# index, day, count ('N926DL', 1, 4)
# index, day, count ('N926XJ', 1, 2)
# index, day, count ('N928DL', 1, 7)
# index, day, count ('N930XJ', 1, 25)
# index, day, count ('N931DL', 1, 3)
# index, day, count ('N932AT', 1, 11)
# index, day, count ('N933XJ', 1, 22)
# index, day, count ('N934XJ', 1, 13)
# index, day, count ('N935DL', 1, 3)
# index, day, count ('N935LR', 1, 0)
# index, day, count ('N935WN', 1, 0)
# index, day, count ('N936DL', 1, 10)
# index, day, count ('N936XJ', 1, 7)
# index, day, count ('N937XJ', 1, 7)
# index, day, count ('N938DL', 1, 1)
# index, day, count ('N939AT', 1, 0)
# index, day, count ('N940DL', 1, 2)
# index, day, count ('N942MQ', 1, 7)
# index, day, count ('N944DL', 1, 4)
# index, day, count ('N944WN', 1, 8)
# index, day, count ('N945AT', 1, 2)
# index, day, count ('N949DL', 1, 61)
# index, day, count ('N949UW', 1, 10)
# index, day, count ('N950AT', 1, 3)
# index, day, count ('N951DL', 1, 15)
# index, day, count ('N953WN', 1, 34)
# index, day, count ('N954AT', 1, 1)
# index, day, count ('N956AT', 1, 23)
# index, day, count ('N956UW', 1, 8)
# index, day, count ('N957DL', 1, 2)
# index, day, count ('N958DL', 1, 21)
# index, day, count ('N960WN', 1, 8)
# index, day, count ('N961WN', 1, 4)
# index, day, count ('N962DL', 1, 1)
# index, day, count ('N963DL', 1, 2)
# index, day, count ('N964DL', 1, 19)
# index, day, count ('N967DL', 1, 17)
# index, day, count ('N968DL', 1, 9)
# index, day, count ('N968WN', 1, 1)
# index, day, count ('N971AT', 1, 10)
# index, day, count ('N972DL', 1, 8)
# index, day, count ('N973DL', 1, 2)
# index, day, count ('N975DL', 1, 9)
# index, day, count ('N980AT', 1, 21)
# index, day, count ('N983DL', 1, 10)
# index, day, count ('N985AT', 1, 1)
# index, day, count ('N992AT', 1, 24)
# index, day, count ('N995AT', 1, 13)
# index, day, count ('N998DL', 1, 13)
# index, day, count ('N9EAMQ', 1, 16)
# index, day, count ('N0EGMQ', 2, 8)
# index, day, count ('N10156', 2, 2)
# index, day, count ('N10575', 2, 2)
# index, day, count ('N11107', 2, 10)
# index, day, count ('N11109', 2, 1)
# index, day, count ('N11119', 2, 2)
# index, day, count ('N11127', 2, 5)
# index, day, count ('N11137', 2, 2)
# index, day, count ('N11140', 2, 5)
# index, day, count ('N11176', 2, 14)
# index, day, count ('N11181', 2, 3)
# index, day, count ('N11189', 2, 13)
# index, day, count ('N11191', 2, 0)
# index, day, count ('N11192', 2, 0)
# index, day, count ('N11193', 2, 3)
# index, day, count ('N11199', 2, 8)
# index, day, count ('N11206', 2, 5)
# index, day, count ('N11536', 2, 23)
# index, day, count ('N11544', 2, 7)
# index, day, count ('N11547', 2, 1)
# index, day, count ('N11548', 2, 2)
# index, day, count ('N11551', 2, 11)
# index, day, count ('N11565', 2, 1)
# index, day, count ('N118US', 2, 0)
# index, day, count ('N12114', 2, 8)
# index, day, count ('N12122', 2, 7)
# index, day, count ('N12126', 2, 5)
# index, day, count ('N12135', 2, 3)
# index, day, count ('N12136', 2, 0)
# index, day, count ('N12157', 2, 7)
# index, day, count ('N12172', 2, 7)
# index, day, count ('N12201', 2, 6)
# index, day, count ('N12540', 2, 22)
# index, day, count ('N12552', 2, 2)
# index, day, count ('N12563', 2, 5)
# index, day, count ('N12564', 2, 1)
# index, day, count ('N12567', 2, 0)
# index, day, count ('N12569', 2, 4)
# index, day, count ('N12900', 2, 7)
# index, day, count ('N12921', 2, 1)
# index, day, count ('N12922', 2, 5)
# index, day, count ('N12924', 2, 0)
# index, day, count ('N12957', 2, 1)
# index, day, count ('N12967', 2, 2)
# index, day, count ('N13118', 2, 18)
# index, day, count ('N13123', 2, 1)
# index, day, count ('N13132', 2, 12)
# index, day, count ('N13133', 2, 3)
# index, day, count ('N131EV', 2, 5)
# index, day, count ('N13202', 2, 2)
# index, day, count ('N13538', 2, 8)
# index, day, count ('N13550', 2, 0)
# index, day, count ('N13553', 2, 0)
# index, day, count ('N13566', 2, 4)
# index, day, count ('N136EV', 2, 4)
# index, day, count ('N138EV', 2, 15)
# index, day, count ('N13903', 2, 6)
# index, day, count ('N13908', 2, 1)
# index, day, count ('N13914', 2, 10)
# index, day, count ('N13949', 2, 0)
# index, day, count ('N13955', 2, 4)
# index, day, count ('N13958', 2, 6)
# index, day, count ('N13968', 2, 14)
# index, day, count ('N13975', 2, 13)
# index, day, count ('N13978', 2, 4)
# index, day, count ('N13979', 2, 6)
# index, day, count ('N13988', 2, 2)
# index, day, count ('N13989', 2, 4)
# index, day, count ('N13992', 2, 3)
# index, day, count ('N13994', 2, 12)
# index, day, count ('N13997', 2, 5)
# index, day, count ('N14105', 2, 5)
# index, day, count ('N14116', 2, 8)
# index, day, count ('N14117', 2, 2)
# index, day, count ('N14143', 2, 17)
# index, day, count ('N14148', 2, 3)
# index, day, count ('N14153', 2, 1)
# index, day, count ('N14158', 2, 1)
# index, day, count ('N14174', 2, 25)
# index, day, count ('N14177', 2, 1)
# index, day, count ('N14179', 2, 0)
# index, day, count ('N14198', 2, 8)
# index, day, count ('N14203', 2, 1)
# index, day, count ('N14228', 2, 12)
# index, day, count ('N14542', 2, 17)
# index, day, count ('N14558', 2, 1)
# index, day, count ('N14562', 2, 7)
# index, day, count ('N14570', 2, 6)
# index, day, count ('N14573', 2, 7)
# index, day, count ('N147PQ', 2, 10)
# index, day, count ('N14904', 2, 2)
# index, day, count ('N14905', 2, 0)
# index, day, count ('N14907', 2, 3)
# index, day, count ('N14916', 2, 1)
# index, day, count ('N14920', 2, 9)
# index, day, count ('N14923', 2, 1)
# index, day, count ('N14950', 2, 3)
# index, day, count ('N14952', 2, 7)
# index, day, count ('N14953', 2, 1)
# index, day, count ('N14959', 2, 3)
# index, day, count ('N14960', 2, 8)
# index, day, count ('N14972', 2, 7)
# index, day, count ('N14977', 2, 12)
# index, day, count ('N14993', 2, 3)
# index, day, count ('N14998', 2, 2)
# index, day, count ('N154DL', 2, 7)
# index, day, count ('N15555', 2, 4)
# index, day, count ('N15910', 2, 32)
# index, day, count ('N15973', 2, 6)
# index, day, count ('N15980', 2, 10)
# index, day, count ('N15983', 2, 8)
# index, day, count ('N15985', 2, 5)
# index, day, count ('N15986', 2, 1)
# index, day, count ('N1603', 2, 0)
# index, day, count ('N16149', 2, 10)
# index, day, count ('N16170', 2, 7)
# index, day, count ('N163US', 2, 20)
# index, day, count ('N16546', 2, 4)
# index, day, count ('N16559', 2, 0)
# index, day, count ('N16561', 2, 4)
# index, day, count ('N16571', 2, 4)
# index, day, count ('N166PQ', 2, 2)
# index, day, count ('N16703', 2, 9)
# index, day, count ('N16918', 2, 14)
# index, day, count ('N16919', 2, 0)
# index, day, count ('N16951', 2, 1)
# index, day, count ('N16961', 2, 2)
# index, day, count ('N16963', 2, 1)
# index, day, count ('N16981', 2, 6)
# index, day, count ('N169UW', 2, 16)
# index, day, count ('N17108', 2, 10)
# index, day, count ('N17128', 2, 12)
# index, day, count ('N17146', 2, 14)
# index, day, count ('N17169', 2, 9)
# index, day, count ('N172US', 2, 22)
# index, day, count ('N173US', 2, 0)
# index, day, count ('N17560', 2, 6)
# index, day, count ('N176AT', 2, 0)
# index, day, count ('N17719', 2, 3)
# index, day, count ('N178JB', 2, 18)
# index, day, count ('N179DN', 2, 14)
# index, day, count ('N18102', 2, 15)
# index, day, count ('N18114', 2, 3)
# index, day, count ('N18119', 2, 1)
# index, day, count ('N18120', 2, 1)
# index, day, count ('N183JB', 2, 19)
# index, day, count ('N184DN', 2, 6)
# index, day, count ('N18556', 2, 9)
# index, day, count ('N18557', 2, 0)
# index, day, count ('N190JB', 2, 28)
# index, day, count ('N19554', 2, 54)
# index, day, count ('N198JB', 2, 26)
# index, day, count ('N19966', 2, 9)
# index, day, count ('N203JB', 2, 40)
# index, day, count ('N204WN', 2, 5)
# index, day, count ('N21129', 2, 15)
# index, day, count ('N21130', 2, 1)
# index, day, count ('N21154', 2, 7)
# index, day, count ('N21197', 2, 3)
# index, day, count ('N211WN', 2, 2)
# index, day, count ('N21537', 2, 7)
# index, day, count ('N216JB', 2, 8)
# index, day, count ('N216WR', 2, 0)
# index, day, count ('N228WN', 2, 35)
# index, day, count ('N22909', 2, 0)
# index, day, count ('N22971', 2, 1)
# index, day, count ('N229JB', 2, 2)
# index, day, count ('N231JB', 2, 13)
# index, day, count ('N23707', 2, 24)
# index, day, count ('N23721', 2, 12)
# index, day, count ('N238JB', 2, 1)
# index, day, count ('N24103', 2, 15)
# index, day, count ('N24128', 2, 5)
# index, day, count ('N24211', 2, 4)
# index, day, count ('N24212', 2, 3)
# index, day, count ('N246LV', 2, 7)
# index, day, count ('N24706', 2, 10)
# index, day, count ('N24729', 2, 13)
# index, day, count ('N247JB', 2, 5)
# index, day, count ('N249JB', 2, 4)
# index, day, count ('N25134', 2, 3)
# index, day, count ('N258JB', 2, 30)
# index, day, count ('N26549', 2, 40)
# index, day, count ('N267JB', 2, 29)
# index, day, count ('N27205', 2, 14)
# index, day, count ('N274JB', 2, 32)
# index, day, count ('N27962', 2, 11)
# index, day, count ('N279PQ', 2, 9)
# index, day, count ('N279WN', 2, 0)
# index, day, count ('N281JB', 2, 17)
# index, day, count ('N283JB', 2, 1)
# index, day, count ('N288WN', 2, 21)
# index, day, count ('N292PQ', 2, 28)
# index, day, count ('N292WN', 2, 1)
# index, day, count ('N296JB', 2, 26)
# index, day, count ('N297PQ', 2, 7)
# index, day, count ('N298JB', 2, 9)
# index, day, count ('N29906', 2, 4)
# index, day, count ('N29917', 2, 4)
# index, day, count ('N301DQ', 2, 6)
# index, day, count ('N301NB', 2, 4)
# index, day, count ('N303DQ', 2, 13)
# index, day, count ('N307DQ', 2, 46)
# index, day, count ('N310NW', 2, 40)
# index, day, count ('N31131', 2, 0)
# index, day, count ('N311US', 2, 0)
# index, day, count ('N313US', 2, 9)
# index, day, count ('N31412', 2, 0)
# index, day, count ('N314NB', 2, 4)
# index, day, count ('N314US', 2, 1)
# index, day, count ('N316JB', 2, 10)
# index, day, count ('N317JB', 2, 7)
# index, day, count ('N318JB', 2, 11)
# index, day, count ('N318US', 2, 8)
# index, day, count ('N319AA', 2, 2)
# index, day, count ('N319US', 2, 12)
# index, day, count ('N320NB', 2, 20)
# index, day, count ('N321NB', 2, 7)
# index, day, count ('N322NB', 2, 7)
# index, day, count ('N322US', 2, 5)
# index, day, count ('N323JB', 2, 18)
# index, day, count ('N324AA', 2, 17)
# index, day, count ('N324JB', 2, 4)
# index, day, count ('N326AT', 2, 21)
# index, day, count ('N326NB', 2, 2)
# index, day, count ('N327NB', 2, 23)
# index, day, count ('N328AA', 2, 10)
# index, day, count ('N328NB', 2, 7)
# index, day, count ('N328NW', 2, 2)
# index, day, count ('N329AA', 2, 4)
# index, day, count ('N329JB', 2, 6)
# index, day, count ('N33182', 2, 25)
# index, day, count ('N33284', 2, 30)
# index, day, count ('N33294', 2, 5)
# index, day, count ('N332AA', 2, 4)
# index, day, count ('N333NB', 2, 18)
# index, day, count ('N335AA', 2, 32)
# index, day, count ('N336AA', 2, 16)
# index, day, count ('N336NB', 2, 13)
# index, day, count ('N336NW', 2, 2)
# index, day, count ('N337JB', 2, 21)
# index, day, count ('N338AA', 2, 30)
# index, day, count ('N338NB', 2, 4)
# index, day, count ('N339AA', 2, 11)
# index, day, count ('N340NW', 2, 31)
# index, day, count ('N34110', 2, 3)
# index, day, count ('N34111', 2, 2)
# index, day, count ('N341NB', 2, 4)
# index, day, count ('N34282', 2, 6)
# index, day, count ('N342NW', 2, 10)
# index, day, count ('N343NW', 2, 6)
# index, day, count ('N34460', 2, 5)
# index, day, count ('N344NB', 2, 5)
# index, day, count ('N345NB', 2, 4)
# index, day, count ('N346JB', 2, 7)
# index, day, count ('N349NB', 2, 28)
# index, day, count ('N349NW', 2, 2)
# index, day, count ('N350NA', 2, 0)
# index, day, count ('N351JB', 2, 2)
# index, day, count ('N351NB', 2, 2)
# index, day, count ('N35271', 2, 12)
# index, day, count ('N353NB', 2, 30)
# index, day, count ('N353NW', 2, 4)
# index, day, count ('N354JB', 2, 10)
# index, day, count ('N355JB', 2, 10)
# index, day, count ('N358JB', 2, 28)
# index, day, count ('N359NW', 2, 15)
# index, day, count ('N360NW', 2, 8)
# index, day, count ('N361SW', 2, 8)
# index, day, count ('N362NW', 2, 17)
# index, day, count ('N36447', 2, 14)
# index, day, count ('N36476', 2, 6)
# index, day, count ('N364NB', 2, 5)
# index, day, count ('N366NW', 2, 13)
# index, day, count ('N367NW', 2, 4)
# index, day, count ('N368NW', 2, 17)
# index, day, count ('N36915', 2, 3)
# index, day, count ('N369NW', 2, 6)
# index, day, count ('N370NW', 2, 14)
# index, day, count ('N371CA', 2, 8)
# index, day, count ('N37252', 2, 12)
# index, day, count ('N37274', 2, 17)
# index, day, count ('N37277', 2, 0)
# index, day, count ('N372DA', 2, 23)
# index, day, count ('N372NW', 2, 4)
# index, day, count ('N3737C', 2, 27)
# index, day, count ('N3739P', 2, 2)
# index, day, count ('N373JB', 2, 7)
# index, day, count ('N37422', 2, 28)
# index, day, count ('N37468', 2, 44)
# index, day, count ('N3746H', 2, 6)
# index, day, count ('N37471', 2, 6)
# index, day, count ('N3764D', 2, 110)
# index, day, count ('N3772H', 2, 41)
# index, day, count ('N378AA', 2, 12)
# index, day, count ('N38268', 2, 36)
# index, day, count ('N383DN', 2, 9)
# index, day, count ('N38403', 2, 4)
# index, day, count ('N38454', 2, 23)
# index, day, count ('N388DA', 2, 35)
# index, day, count ('N389DA', 2, 6)
# index, day, count ('N391DA', 2, 12)
# index, day, count ('N39416', 2, 16)
# index, day, count ('N39418', 2, 1)
# index, day, count ('N39450', 2, 5)
# index, day, count ('N3AAAA', 2, 53)
# index, day, count ('N3AJAA', 2, 24)
# index, day, count ('N3AKAA', 2, 0)
# index, day, count ('N3ASAA', 2, 14)
# index, day, count ('N3BAAA', 2, 20)
# index, day, count ('N3BPAA', 2, 27)
# index, day, count ('N3BRAA', 2, 3)
# index, day, count ('N3BSAA', 2, 2)
# index, day, count ('N3BWAA', 2, 6)
# index, day, count ('N3CHAA', 2, 27)
# index, day, count ('N3CKAA', 2, 5)
# index, day, count ('N3CTAA', 2, 16)
# index, day, count ('N3CWAA', 2, 1)
# index, day, count ('N3CXAA', 2, 0)
# index, day, count ('N3DCAA', 2, 4)
# index, day, count ('N3DPAA', 2, 14)
# index, day, count ('N3EDAA', 2, 23)
# index, day, count ('N3EVAA', 2, 18)
# index, day, count ('N3EXAA', 2, 5)
# index, day, count ('N3FBAA', 2, 6)
# index, day, count ('N3GDAA', 2, 66)
# index, day, count ('N3HNAA', 2, 76)
# index, day, count ('N3HRAA', 2, 8)
# index, day, count ('N3HXAA', 2, 8)
# index, day, count ('N3JJAA', 2, 13)
# index, day, count ('N3KLAA', 2, 37)
# index, day, count ('N3KNAA', 2, 3)
# index, day, count ('N401UA', 2, 11)
# index, day, count ('N401WN', 2, 2)
# index, day, count ('N403UA', 2, 12)
# index, day, count ('N406UA', 2, 9)
# index, day, count ('N408AS', 2, 7)
# index, day, count ('N408WN', 2, 0)
# index, day, count ('N410UA', 2, 6)
# index, day, count ('N41104', 2, 0)
# index, day, count ('N411UA', 2, 9)
# index, day, count ('N412UA', 2, 2)
# index, day, count ('N421UA', 2, 33)
# index, day, count ('N427UA', 2, 25)
# index, day, count ('N428UA', 2, 5)
# index, day, count ('N433LV', 2, 16)
# index, day, count ('N433UA', 2, 1)
# index, day, count ('N436UA', 2, 15)
# index, day, count ('N438WN', 2, 11)
# index, day, count ('N439UA', 2, 1)
# index, day, count ('N440UA', 2, 7)
# index, day, count ('N441UA', 2, 2)
# index, day, count ('N442UA', 2, 1)
# index, day, count ('N443UA', 2, 2)
# index, day, count ('N448UA', 2, 11)
# index, day, count ('N454UA', 2, 26)
# index, day, count ('N457UA', 2, 10)
# index, day, count ('N459WN', 2, 11)
# index, day, count ('N463WN', 2, 23)
# index, day, count ('N464WN', 2, 6)
# index, day, count ('N469UA', 2, 26)
# index, day, count ('N473UA', 2, 20)
# index, day, count ('N474UA', 2, 8)
# index, day, count ('N479UA', 2, 25)
# index, day, count ('N483AA', 2, 21)
# index, day, count ('N483WN', 2, 4)
# index, day, count ('N48901', 2, 36)
# index, day, count ('N490UA', 2, 9)
# index, day, count ('N494UA', 2, 17)
# index, day, count ('N497UA', 2, 14)
# index, day, count ('N4UCAA', 2, 8)
# index, day, count ('N4WTAA', 2, 12)
# index, day, count ('N4WVAA', 2, 0)
# index, day, count ('N4XEAA', 2, 5)
# index, day, count ('N4YDAA', 2, 39)
# index, day, count ('N4YFAA', 2, 1)
# index, day, count ('N500MQ', 2, 22)
# index, day, count ('N501MQ', 2, 9)
# index, day, count ('N503MQ', 2, 27)
# index, day, count ('N503UA', 2, 2)
# index, day, count ('N505JB', 2, 24)
# index, day, count ('N505MQ', 2, 7)
# index, day, count ('N506JB', 2, 15)
# index, day, count ('N506MQ', 2, 2)
# index, day, count ('N507JB', 2, 13)
# index, day, count ('N507MQ', 2, 12)
# index, day, count ('N508MQ', 2, 27)
# index, day, count ('N508UA', 2, 2)
# index, day, count ('N509JB', 2, 14)
# index, day, count ('N509MQ', 2, 7)
# index, day, count ('N510JB', 2, 8)
# index, day, count ('N510MQ', 2, 12)
# index, day, count ('N510UA', 2, 4)
# index, day, count ('N510UW', 2, 0)
# index, day, count ('N512MQ', 2, 19)
# index, day, count ('N512UA', 2, 8)
# index, day, count ('N513MQ', 2, 4)
# index, day, count ('N514MQ', 2, 10)
# index, day, count ('N515MQ', 2, 7)
# index, day, count ('N515UA', 2, 1)
# index, day, count ('N516JB', 2, 10)
# index, day, count ('N516MQ', 2, 6)
# index, day, count ('N517MQ', 2, 14)
# index, day, count ('N518UA', 2, 18)
# index, day, count ('N519MQ', 2, 17)
# index, day, count ('N520JB', 2, 12)
# index, day, count ('N520MQ', 2, 0)
# index, day, count ('N520UW', 2, 5)
# index, day, count ('N521MQ', 2, 16)
# index, day, count ('N522MQ', 2, 13)
# index, day, count ('N522UA', 2, 2)
# index, day, count ('N523JB', 2, 8)
# index, day, count ('N523MQ', 2, 5)
# index, day, count ('N524MQ', 2, 18)
# index, day, count ('N524UA', 2, 3)
# index, day, count ('N525UA', 2, 19)
# index, day, count ('N526MQ', 2, 11)
# index, day, count ('N527JB', 2, 13)
# index, day, count ('N527MQ', 2, 6)
# index, day, count ('N528MQ', 2, 13)
# index, day, count ('N529UA', 2, 20)
# index, day, count ('N530MQ', 2, 8)
# index, day, count ('N530VA', 2, 2)
# index, day, count ('N531JB', 2, 5)
# index, day, count ('N531MQ', 2, 1)
# index, day, count ('N532MQ', 2, 5)
# index, day, count ('N534MQ', 2, 29)
# index, day, count ('N535JB', 2, 4)
# index, day, count ('N536JB', 2, 15)
# index, day, count ('N536UA', 2, 3)
# index, day, count ('N537AA', 2, 3)
# index, day, count ('N537JB', 2, 3)
# index, day, count ('N538CA', 2, 15)
# index, day, count ('N539MQ', 2, 15)
# index, day, count ('N539UW', 2, 8)
# index, day, count ('N541UA', 2, 10)
# index, day, count ('N542AA', 2, 7)
# index, day, count ('N542MQ', 2, 8)
# index, day, count ('N542UW', 2, 3)
# index, day, count ('N543AA', 2, 0)
# index, day, count ('N543MQ', 2, 1)
# index, day, count ('N544MQ', 2, 11)
# index, day, count ('N546AA', 2, 8)
# index, day, count ('N547AA', 2, 12)
# index, day, count ('N547JB', 2, 11)
# index, day, count ('N547UA', 2, 0)
# index, day, count ('N551UW', 2, 21)
# index, day, count ('N552JB', 2, 7)
# index, day, count ('N552UA', 2, 0)
# index, day, count ('N552UW', 2, 3)
# index, day, count ('N553UA', 2, 5)
# index, day, count ('N554JB', 2, 8)
# index, day, count ('N554UA', 2, 2)
# index, day, count ('N555UA', 2, 22)
# index, day, count ('N556JB', 2, 9)
# index, day, count ('N556NW', 2, 1)
# index, day, count ('N556UA', 2, 3)
# index, day, count ('N558JB', 2, 27)
# index, day, count ('N558UA', 2, 0)
# index, day, count ('N560UA', 2, 22)
# index, day, count ('N561JB', 2, 13)
# index, day, count ('N561UW', 2, 7)
# index, day, count ('N562JB', 2, 1)
# index, day, count ('N563JB', 2, 9)
# index, day, count ('N564JB', 2, 14)
# index, day, count ('N564UW', 2, 6)
# index, day, count ('N565JB', 2, 8)
# index, day, count ('N566UA', 2, 20)
# index, day, count ('N567UA', 2, 1)
# index, day, count ('N568AA', 2, 1)
# index, day, count ('N569JB', 2, 22)
# index, day, count ('N570AA', 2, 8)
# index, day, count ('N571JB', 2, 20)
# index, day, count ('N571UA', 2, 1)
# index, day, count ('N572UA', 2, 3)
# index, day, count ('N580JB', 2, 53)
# index, day, count ('N582AA', 2, 11)
# index, day, count ('N585JB', 2, 35)
# index, day, count ('N586JB', 2, 10)
# index, day, count ('N587AA', 2, 4)
# index, day, count ('N588JB', 2, 15)
# index, day, count ('N589JB', 2, 14)
# index, day, count ('N590JB', 2, 11)
# index, day, count ('N591JB', 2, 4)
# index, day, count ('N592AA', 2, 0)
# index, day, count ('N592JB', 2, 5)
# index, day, count ('N593UA', 2, 16)
# index, day, count ('N594UA', 2, 23)
# index, day, count ('N595JB', 2, 11)
# index, day, count ('N596AA', 2, 10)
# index, day, count ('N597JB', 2, 18)
# index, day, count ('N597UA', 2, 5)
# index, day, count ('N599JB', 2, 23)
# index, day, count ('N5CYAA', 2, 16)
# index, day, count ('N5DTAA', 2, 12)
# index, day, count ('N5EAAA', 2, 7)
# index, day, count ('N5ELAA', 2, 5)
# index, day, count ('N5EUAA', 2, 15)
# index, day, count ('N5FFAA', 2, 24)
# index, day, count ('N5FRAA', 2, 20)
# index, day, count ('N5PBMQ', 2, 14)
# index, day, count ('N600LR', 2, 5)
# index, day, count ('N600QX', 2, 1)
# index, day, count ('N601LR', 2, 4)
# index, day, count ('N602LR', 2, 15)
# index, day, count ('N603JB', 2, 13)
# index, day, count ('N604LR', 2, 6)
# index, day, count ('N605MQ', 2, 18)
# index, day, count ('N605QX', 2, 2)
# index, day, count ('N606JB', 2, 6)
# index, day, count ('N608JB', 2, 20)
# index, day, count ('N608QX', 2, 4)
# index, day, count ('N611QX', 2, 8)
# index, day, count ('N612JB', 2, 10)
# index, day, count ('N613JB', 2, 16)
# index, day, count ('N614DL', 2, 0)
# index, day, count ('N614QX', 2, 4)
# index, day, count ('N615QX', 2, 13)
# index, day, count ('N618DL', 2, 12)
# index, day, count ('N618JB', 2, 5)
# index, day, count ('N618MQ', 2, 0)
# index, day, count ('N623JB', 2, 32)
# index, day, count ('N623MQ', 2, 1)
# index, day, count ('N624JB', 2, 26)
# index, day, count ('N626MQ', 2, 20)
# index, day, count ('N627MQ', 2, 12)
# index, day, count ('N627VA', 2, 2)
# index, day, count ('N628VA', 2, 4)
# index, day, count ('N629JB', 2, 12)
# index, day, count ('N631VA', 2, 26)
# index, day, count ('N632JB', 2, 0)
# index, day, count ('N632VA', 2, 2)
# index, day, count ('N633VA', 2, 16)
# index, day, count ('N634JB', 2, 6)
# index, day, count ('N634VA', 2, 2)
# index, day, count ('N636JB', 2, 14)
# index, day, count ('N638JB', 2, 28)
# index, day, count ('N640AW', 2, 17)
# index, day, count ('N640JB', 2, 4)
# index, day, count ('N641JB', 2, 7)
# index, day, count ('N644DL', 2, 24)
# index, day, count ('N644JB', 2, 7)
# index, day, count ('N644MQ', 2, 0)
# index, day, count ('N648DL', 2, 31)
# index, day, count ('N648MQ', 2, 6)
# index, day, count ('N650DL', 2, 9)
# index, day, count ('N650MQ', 2, 2)
# index, day, count ('N651AW', 2, 0)
# index, day, count ('N651JB', 2, 10)
# index, day, count ('N655JB', 2, 32)
# index, day, count ('N655MQ', 2, 0)
# index, day, count ('N656JB', 2, 16)
# index, day, count ('N658JB', 2, 28)
# index, day, count ('N660AW', 2, 15)
# index, day, count ('N662JB', 2, 21)
# ...
# index, day, count ('N909EV', 30, 21)
# index, day, count ('N909FJ', 30, 0)
# index, day, count ('N909XJ', 30, 2)
# index, day, count ('N910WN', 30, 7)
# index, day, count ('N910XJ', 30, 5)
# index, day, count ('N912XJ', 30, 11)
# index, day, count ('N916XJ', 30, 46)
# index, day, count ('N917XJ', 30, 8)
# index, day, count ('N918DE', 30, 0)
# index, day, count ('N918WN', 30, 4)
# index, day, count ('N918XJ', 30, 5)
# index, day, count ('N920XJ', 30, 23)
# index, day, count ('N921XJ', 30, 5)
# index, day, count ('N922WN', 30, 6)
# index, day, count ('N922XJ', 30, 0)
# index, day, count ('N923AT', 30, 2)
# index, day, count ('N923WN', 30, 3)
# index, day, count ('N924XJ', 30, 11)
# index, day, count ('N925WN', 30, 3)
# index, day, count ('N926XJ', 30, 13)
# index, day, count ('N927WN', 30, 4)
# index, day, count ('N930WN', 30, 42)
# index, day, count ('N930XJ', 30, 0)
# index, day, count ('N931DL', 30, 0)
# index, day, count ('N933XJ', 30, 24)
# index, day, count ('N934XJ', 30, 6)
# index, day, count ('N935AT', 30, 3)
# index, day, count ('N935XJ', 30, 8)
# index, day, count ('N936XJ', 30, 6)
# index, day, count ('N938DL', 30, 11)
# index, day, count ('N942MQ', 30, 28)
# index, day, count ('N945WN', 30, 29)
# index, day, count ('N946AT', 30, 1)
# index, day, count ('N946UW', 30, 11)
# index, day, count ('N947WN', 30, 7)
# index, day, count ('N951FR', 30, 27)
# index, day, count ('N953UW', 30, 38)
# index, day, count ('N954AT', 30, 1)
# index, day, count ('N955DL', 30, 4)
# index, day, count ('N955UW', 30, 4)
# index, day, count ('N961UW', 30, 70)
# index, day, count ('N963UW', 30, 19)
# index, day, count ('N967DL', 30, 22)
# index, day, count ('N968DL', 30, 11)
# index, day, count ('N970AT', 30, 6)
# index, day, count ('N976DL', 30, 24)
# index, day, count ('N978SW', 30, 16)
# index, day, count ('N982DL', 30, 19)
# index, day, count ('N984DL', 30, 3)
# index, day, count ('N986DL', 30, 3)
# index, day, count ('N989AT', 30, 6)
# index, day, count ('N990AT', 30, 1)
# index, day, count ('N994AT', 30, 15)
# index, day, count ('N998AT', 30, 9)
# index, day, count ('N998DL', 30, 1)
# index, day, count ('N0EGMQ', 31, 12)
# index, day, count ('N10575', 31, 5)
# index, day, count ('N11113', 31, 11)
# index, day, count ('N11121', 31, 4)
# index, day, count ('N11140', 31, 3)
# index, day, count ('N11176', 31, 2)
# index, day, count ('N11184', 31, 3)
# index, day, count ('N11189', 31, 1)
# index, day, count ('N11193', 31, 1)
# index, day, count ('N11194', 31, 1)
# index, day, count ('N11199', 31, 0)
# index, day, count ('N11536', 31, 12)
# index, day, count ('N11539', 31, 2)
# index, day, count ('N11544', 31, 0)
# index, day, count ('N11548', 31, 4)
# index, day, count ('N11565', 31, 4)
# index, day, count ('N12122', 31, 8)
# index, day, count ('N12126', 31, 1)
# index, day, count ('N12136', 31, 3)
# index, day, count ('N12157', 31, 2)
# index, day, count ('N12163', 31, 4)
# index, day, count ('N12166', 31, 2)
# index, day, count ('N12175', 31, 7)
# index, day, count ('N12195', 31, 2)
# index, day, count ('N12225', 31, 11)
# index, day, count ('N12238', 31, 0)
# index, day, count ('N12540', 31, 5)
# index, day, count ('N12552', 31, 1)
# index, day, count ('N12563', 31, 2)
# index, day, count ('N12900', 31, 14)
# index, day, count ('N12921', 31, 1)
# index, day, count ('N12967', 31, 10)
# index, day, count ('N12996', 31, 0)
# index, day, count ('N13124', 31, 7)
# index, day, count ('N13133', 31, 2)
# index, day, count ('N13202', 31, 6)
# index, day, count ('N13538', 31, 2)
# index, day, count ('N13553', 31, 8)
# index, day, count ('N13566', 31, 0)
# index, day, count ('N13955', 31, 21)
# index, day, count ('N13956', 31, 1)
# index, day, count ('N13958', 31, 1)
# index, day, count ('N13968', 31, 8)
# index, day, count ('N13969', 31, 1)
# index, day, count ('N13975', 31, 1)
# index, day, count ('N13992', 31, 16)
# index, day, count ('N13995', 31, 6)
# index, day, count ('N14105', 31, 2)
# index, day, count ('N14106', 31, 1)
# index, day, count ('N14116', 31, 4)
# index, day, count ('N14162', 31, 18)
# index, day, count ('N14174', 31, 5)
# index, day, count ('N14188', 31, 7)
# index, day, count ('N14198', 31, 1)
# index, day, count ('N14219', 31, 8)
# index, day, count ('N14250', 31, 14)
# index, day, count ('N14573', 31, 21)
# index, day, count ('N14704', 31, 1)
# index, day, count ('N14904', 31, 11)
# index, day, count ('N14907', 31, 2)
# index, day, count ('N14920', 31, 5)
# index, day, count ('N14923', 31, 0)
# index, day, count ('N14952', 31, 4)
# index, day, count ('N14959', 31, 5)
# index, day, count ('N14960', 31, 0)
# index, day, count ('N14993', 31, 13)
# index, day, count ('N15572', 31, 8)
# index, day, count ('N15980', 31, 25)
# index, day, count ('N15985', 31, 8)
# index, day, count ('N15986', 31, 0)
# index, day, count ('N16149', 31, 2)
# index, day, count ('N16151', 31, 2)
# index, day, count ('N16170', 31, 1)
# index, day, count ('N16178', 31, 0)
# index, day, count ('N16541', 31, 13)
# index, day, count ('N16546', 31, 1)
# index, day, count ('N16561', 31, 4)
# index, day, count ('N16571', 31, 0)
# index, day, count ('N167US', 31, 16)
# index, day, count ('N16911', 31, 0)
# index, day, count ('N16918', 31, 2)
# index, day, count ('N16919', 31, 0)
# index, day, count ('N16987', 31, 13)
# index, day, count ('N16999', 31, 2)
# index, day, count ('N17108', 31, 6)
# index, day, count ('N17560', 31, 39)
# index, day, count ('N178JB', 31, 9)
# index, day, count ('N18557', 31, 59)
# index, day, count ('N19141', 31, 27)
# index, day, count ('N19966', 31, 46)
# index, day, count ('N1EAMQ', 31, 4)
# index, day, count ('N201FR', 31, 4)
# index, day, count ('N203JB', 31, 1)
# index, day, count ('N206FR', 31, 3)
# index, day, count ('N21129', 31, 8)
# index, day, count ('N21537', 31, 14)
# index, day, count ('N216JB', 31, 0)
# index, day, count ('N228JB', 31, 6)
# index, day, count ('N229JB', 31, 10)
# index, day, count ('N231JB', 31, 10)
# index, day, count ('N236WN', 31, 9)
# index, day, count ('N239JB', 31, 22)
# index, day, count ('N239WN', 31, 0)
# index, day, count ('N24103', 31, 1)
# index, day, count ('N24128', 31, 0)
# index, day, count ('N24224', 31, 10)
# index, day, count ('N24706', 31, 5)
# index, day, count ('N24729', 31, 3)
# index, day, count ('N249JB', 31, 10)
# index, day, count ('N25134', 31, 3)
# index, day, count ('N25705', 31, 4)
# index, day, count ('N258JB', 31, 1)
# index, day, count ('N261WN', 31, 3)
# index, day, count ('N26545', 31, 8)
# index, day, count ('N27152', 31, 29)
# index, day, count ('N27205', 31, 8)
# index, day, count ('N273JB', 31, 5)
# index, day, count ('N27421', 31, 1)
# index, day, count ('N276WN', 31, 8)
# index, day, count ('N27962', 31, 14)
# index, day, count ('N279JB', 31, 3)
# index, day, count ('N281JB', 31, 1)
# index, day, count ('N282WN', 31, 3)
# index, day, count ('N289CT', 31, 14)
# index, day, count ('N292JB', 31, 12)
# index, day, count ('N295WN', 31, 13)
# index, day, count ('N296JB', 31, 6)
# index, day, count ('N298JB', 31, 11)
# index, day, count ('N309DE', 31, 55)
# index, day, count ('N317US', 31, 43)
# index, day, count ('N318JB', 31, 0)
# index, day, count ('N319AA', 31, 9)
# index, day, count ('N327AA', 31, 84)
# index, day, count ('N329JB', 31, 24)
# index, day, count ('N329NW', 31, 2)
# index, day, count ('N330NW', 31, 2)
# index, day, count ('N33203', 31, 12)
# index, day, count ('N332AA', 31, 20)
# index, day, count ('N334JB', 31, 17)
# index, day, count ('N336NW', 31, 29)
# index, day, count ('N33714', 31, 1)
# index, day, count ('N337JB', 31, 1)
# index, day, count ('N339AA', 31, 17)
# index, day, count ('N34131', 31, 18)
# index, day, count ('N34282', 31, 17)
# index, day, count ('N342NB', 31, 0)
# index, day, count ('N354JB', 31, 95)
# index, day, count ('N360NW', 31, 38)
# index, day, count ('N36915', 31, 60)
# index, day, count ('N369NW', 31, 3)
# index, day, count ('N3730B', 31, 38)
# index, day, count ('N37462', 31, 65)
# index, day, count ('N374JB', 31, 25)
# index, day, count ('N381DN', 31, 82)
# index, day, count ('N38257', 31, 1)
# index, day, count ('N38454', 31, 18)
# index, day, count ('N38467', 31, 3)
# index, day, count ('N388DA', 31, 18)
# index, day, count ('N39463', 31, 34)
# index, day, count ('N394AA', 31, 2)
# index, day, count ('N3ABAA', 31, 24)
# index, day, count ('N3ANAA', 31, 21)
# index, day, count ('N3BAAA', 31, 9)
# index, day, count ('N3BKAA', 31, 15)
# index, day, count ('N3BRAA', 31, 7)
# index, day, count ('N3BWAA', 31, 9)
# index, day, count ('N3DSAA', 31, 34)
# index, day, count ('N3DTAA', 31, 0)
# index, day, count ('N3FAAA', 31, 32)
# index, day, count ('N3GDAA', 31, 25)
# index, day, count ('N3GKAA', 31, 11)
# index, day, count ('N3HLAA', 31, 22)
# index, day, count ('N3JFAA', 31, 23)
# index, day, count ('N3JWAA', 31, 18)
# index, day, count ('N402AS', 31, 35)
# index, day, count ('N406UA', 31, 13)
# index, day, count ('N418UA', 31, 30)
# index, day, count ('N421UA', 31, 6)
# index, day, count ('N426UA', 31, 11)
# index, day, count ('N433LV', 31, 9)
# index, day, count ('N443UA', 31, 21)
# index, day, count ('N449UA', 31, 10)
# index, day, count ('N465WN', 31, 49)
# index, day, count ('N473WN', 31, 28)
# index, day, count ('N474AA', 31, 3)
# index, day, count ('N477UA', 31, 12)
# index, day, count ('N478UA', 31, 1)
# index, day, count ('N478WN', 31, 0)
# index, day, count ('N479AA', 31, 1)
# index, day, count ('N482AA', 31, 15)
# index, day, count ('N484UA', 31, 2)
# index, day, count ('N489UA', 31, 26)
# index, day, count ('N496WN', 31, 20)
# index, day, count ('N4XFAA', 31, 22)
# index, day, count ('N4XTAA', 31, 5)
# index, day, count ('N4YDAA', 31, 10)
# index, day, count ('N4YEAA', 31, 0)
# index, day, count ('N500MQ', 31, 12)
# index, day, count ('N501MJ', 31, 1)
# index, day, count ('N502UA', 31, 18)
# index, day, count ('N503JB', 31, 1)
# index, day, count ('N503UA', 31, 4)
# index, day, count ('N505JB', 31, 15)
# index, day, count ('N505MQ', 31, 2)
# index, day, count ('N505UA', 31, 2)
# index, day, count ('N506MQ', 31, 10)
# index, day, count ('N507MJ', 31, 4)
# index, day, count ('N507MQ', 31, 3)
# index, day, count ('N510MQ', 31, 44)
# index, day, count ('N516JB', 31, 40)
# index, day, count ('N517MQ', 31, 6)
# index, day, count ('N519JB', 31, 15)
# index, day, count ('N520JB', 31, 12)
# index, day, count ('N520MQ', 31, 2)
# index, day, count ('N520UA', 31, 3)
# index, day, count ('N523MQ', 31, 31)
# index, day, count ('N527AA', 31, 37)
# index, day, count ('N527MQ', 31, 3)
# index, day, count ('N528MQ', 31, 6)
# index, day, count ('N531MQ', 31, 25)
# index, day, count ('N532MQ', 31, 4)
# index, day, count ('N53442', 31, 3)
# index, day, count ('N535MQ', 31, 11)
# index, day, count ('N536JB', 31, 3)
# index, day, count ('N537MQ', 31, 15)
# index, day, count ('N539MQ', 31, 14)
# index, day, count ('N544MQ', 31, 19)
# index, day, count ('N545UA', 31, 1)
# index, day, count ('N546AA', 31, 3)
# index, day, count ('N550WN', 31, 29)
# index, day, count ('N554UA', 31, 33)
# index, day, count ('N563JB', 31, 74)
# index, day, count ('N568AA', 31, 39)
# index, day, count ('N569UA', 31, 15)
# index, day, count ('N570AA', 31, 0)
# index, day, count ('N572UA', 31, 11)
# index, day, count ('N577AA', 31, 11)
# index, day, count ('N57852', 31, 3)
# index, day, count ('N584JB', 31, 39)
# index, day, count ('N585JB', 31, 3)
# index, day, count ('N587JB', 31, 14)
# index, day, count ('N590JB', 31, 29)
# index, day, count ('N599JB', 31, 66)
# index, day, count ('N5DSAA', 31, 12)
# index, day, count ('N5DTAA', 31, 1)
# index, day, count ('N5EBAA', 31, 5)
# index, day, count ('N5FGAA', 31, 22)
# index, day, count ('N5FKAA', 31, 7)
# index, day, count ('N5FRAA', 31, 8)
# index, day, count ('N5PBMQ', 31, 7)
# index, day, count ('N603AT', 31, 13)
# index, day, count ('N605LR', 31, 16)
# index, day, count ('N606MQ', 31, 9)
# index, day, count ('N607AT', 31, 0)
# index, day, count ('N622VA', 31, 73)
# index, day, count ('N624AG', 31, 5)
# index, day, count ('N625VA', 31, 13)
# index, day, count ('N627JB', 31, 3)
# index, day, count ('N628VA', 31, 7)
# index, day, count ('N633JB', 31, 29)
# index, day, count ('N640JB', 31, 52)
# index, day, count ('N641JB', 31, 5)
# index, day, count ('N642VA', 31, 11)
# index, day, count ('N644JB', 31, 11)
# index, day, count ('N650AW', 31, 25)
# index, day, count ('N652JB', 31, 14)
# index, day, count ('N661AW', 31, 57)
# index, day, count ('N661JB', 31, 4)
# index, day, count ('N663JB', 31, 7)
# index, day, count ('N665JB', 31, 11)
# index, day, count ('N6702', 31, 13)
# index, day, count ('N678MQ', 31, 30)
# index, day, count ('N682MQ', 31, 10)
# index, day, count ('N684DA', 31, 3)
# index, day, count ('N686DA', 31, 0)
# index, day, count ('N697DL', 31, 21)
# index, day, count ('N702UW', 31, 18)
# index, day, count ('N705SW', 31, 24)
# index, day, count ('N707EV', 31, 17)
# index, day, count ('N709EV', 31, 17)
# index, day, count ('N710EV', 31, 11)
# index, day, count ('N711HK', 31, 4)
# index, day, count ('N711MQ', 31, 1)
# index, day, count ('N712JB', 31, 10)
# index, day, count ('N713EV', 31, 5)
# index, day, count ('N716EV', 31, 33)
# index, day, count ('N718TW', 31, 23)
# index, day, count ('N719EV', 31, 1)
# index, day, count ('N720EV', 31, 4)
# index, day, count ('N722MQ', 31, 21)
# index, day, count ('N722TW', 31, 2)
# index, day, count ('N722US', 31, 0)
# index, day, count ('N723MQ', 31, 5)
# index, day, count ('N730MQ', 31, 46)
# index, day, count ('N73291', 31, 12)
# index, day, count ('N732US', 31, 5)
# index, day, count ('N734MQ', 31, 4)
# index, day, count ('N736MQ', 31, 7)
# index, day, count ('N737MQ', 31, 2)
# index, day, count ('N738EV', 31, 3)
# index, day, count ('N741EV', 31, 10)
# index, day, count ('N748EV', 31, 33)
# index, day, count ('N751EV', 31, 14)
# index, day, count ('N75432', 31, 10)
# index, day, count ('N755EV', 31, 15)
# index, day, count ('N75851', 31, 16)
# index, day, count ('N759EV', 31, 8)
# index, day, count ('N760JB', 31, 13)
# index, day, count ('N76529', 31, 50)
# index, day, count ('N7702A', 31, 39)
# index, day, count ('N77258', 31, 11)
# index, day, count ('N77295', 31, 7)
# index, day, count ('N776WN', 31, 31)
# index, day, count ('N804MQ', 31, 101)
# index, day, count ('N805AY', 31, 3)
# index, day, count ('N805UA', 31, 6)
# index, day, count ('N806JB', 31, 5)
# index, day, count ('N806UA', 31, 2)
# index, day, count ('N807MQ', 31, 3)
# index, day, count ('N809UA', 31, 8)
# index, day, count ('N815MQ', 31, 20)
# index, day, count ('N820UA', 31, 25)
# index, day, count ('N824MQ', 31, 20)
# index, day, count ('N825AS', 31, 4)
# index, day, count ('N825AY', 31, 0)
# index, day, count ('N827AS', 31, 4)
# index, day, count ('N828AW', 31, 12)
# index, day, count ('N829AS', 31, 9)
# index, day, count ('N830AS', 31, 6)
# index, day, count ('N8317M', 31, 5)
# index, day, count ('N832AS', 31, 7)
# index, day, count ('N833AY', 31, 8)
# index, day, count ('N836VA', 31, 29)
# index, day, count ('N837VA', 31, 0)
# index, day, count ('N838UA', 31, 0)
# index, day, count ('N843VA', 31, 29)
# index, day, count ('N844MQ', 31, 2)
# index, day, count ('N846UA', 31, 17)
# index, day, count ('N8475B', 31, 3)
# index, day, count ('N8543F', 31, 54)
# index, day, count ('N855MQ', 31, 2)
# index, day, count ('N8560F', 31, 7)
# index, day, count ('N8733G', 31, 31)
# index, day, count ('N8736A', 31, 0)
# index, day, count ('N87507', 31, 2)
# index, day, count ('N8808H', 31, 19)
# index, day, count ('N8894A', 31, 10)
# index, day, count ('N8907A', 31, 3)
# index, day, count ('N8980A', 31, 25)
# index, day, count ('N902XJ', 31, 24)
# index, day, count ('N903XJ', 31, 6)
# index, day, count ('N904XJ', 31, 5)
# index, day, count ('N906WN', 31, 14)
# index, day, count ('N909EV', 31, 30)
# index, day, count ('N909XJ', 31, 2)
# index, day, count ('N910XJ', 31, 9)
# index, day, count ('N912XJ', 31, 5)
# index, day, count ('N913XJ', 31, 12)
# index, day, count ('N917XJ', 31, 29)
# index, day, count ('N918XJ', 31, 4)
# index, day, count ('N919DL', 31, 4)
# index, day, count ('N921XJ', 31, 20)
# index, day, count ('N922XJ', 31, 4)
# index, day, count ('N923DL', 31, 3)
# index, day, count ('N923FJ', 31, 0)
# index, day, count ('N924XJ', 31, 17)
# index, day, count ('N927XJ', 31, 27)
# index, day, count ('N933DN', 31, 39)
# index, day, count ('N934XJ', 31, 1)
# index, day, count ('N935DL', 31, 4)
# index, day, count ('N936DL', 31, 6)
# index, day, count ('N944UW', 31, 37)
# index, day, count ('N946UW', 31, 14)
# index, day, count ('N948DL', 31, 12)
# index, day, count ('N959UW', 31, 62)
# index, day, count ('N962WN', 31, 13)
# index, day, count ('N964WN', 31, 13)
# index, day, count ('N966AT', 31, 4)
# index, day, count ('N967AT', 31, 4)
# index, day, count ('N967UW', 31, 2)
# index, day, count ('N969AT', 31, 3)
# index, day, count ('N979DL', 31, 24)
# index, day, count ('N980DL', 31, 1)
# index, day, count ('N998DL', 31, 30)
